# %%
import os
import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from flask import Flask, jsonify

#################################################
# Database Setup
#################################################
engine = create_engine(f"postgres://postgres:postgres@localhost:5432/houston_statistics_db")

# reflect an existing database into a new model
Base = automap_base()
Base.prepare(engine, reflect=True)

# Save reference to the table
oil = Base.classes.oilprice
engy_employees = Base.classes.energy_extraction_employees
employees = Base.classes.nonfarm_employees
population = Base.classes.population
housing = Base.classes.housing_index

# %%
# Query population
session = Session(engine)
results = session.query(population).all()
session.close()
    #Create a dictionary from the row data and append to station data
pop = []
for data in results:
    pop_dict = {}
    pop_dict["year"] = data.year
    pop_dict["population"] = data.population
    pop.append(pop_dict)

pop
# Out:
# [{'year': 2000, 'population': 4739414},
#  {'year': 2001, 'population': 4851189},
#  {'year': 2002, 'population': 4978638},
#  {'year': 2003, 'population': 5084017},
#  {'year': 2004, 'population': 5190444},
#  {'year': 2005, 'population': 5299566},
#  {'year': 2006, 'population': 5484883},
#  {'year': 2007, 'population': 5597674},
#  {'year': 2008, 'population': 5726705},
#  {'year': 2009, 'population': 5867489},
#  {'year': 2010, 'population': 5947409},
#  {'year': 2011, 'population': 6056366},
#  {'year': 2012, 'population': 6184861},
#  {'year': 2013, 'population': 6330656},
#  {'year': 2014, 'population': 6503618},
#  {'year': 2015, 'population': 6676565},
#  {'year': 2016, 'population': 6812260},
#  {'year': 2017, 'population': 6905695},
#  {'year': 2018, 'population': 6997384}]

# %%
    # Query population
session = Session(engine)
results = session.query(housing, oil, engy_employees, employees, population).filter(housing.year == oil.year, housing.year == engy_employees.year, housing.year == employees.year, housing.year == population.year).all()
session.close()

results

#     # Convert list of tuples into normal list
# pop = []

# len(results)


# print(results[0])
    

# pop
# Out:
# [(<sqlalchemy.ext.automap.housing_index at 0x1c92beb3cc0>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92beb3b00>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92beb3d30>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92beb3da0>,
#   <sqlalchemy.ext.automap.population at 0x1c92beb3898>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c933f2de48>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c933f2da90>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c933f2db38>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c933f2dbe0>,
#   <sqlalchemy.ext.automap.population at 0x1c933f2dc88>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c933f2dd30>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c933f2d6a0>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c933f2d208>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c933f2d1d0>,
#   <sqlalchemy.ext.automap.population at 0x1c933f2d710>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c933f2d898>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c933f2d7b8>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c933f2d748>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c933f2d940>,
#   <sqlalchemy.ext.automap.population at 0x1c933f2d908>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c933f2d9e8>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92b9f1668>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92b9f10b8>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92b9f1320>,
#   <sqlalchemy.ext.automap.population at 0x1c92b9f1278>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c92b9f1550>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92b9f14a8>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92b9f1400>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92b9f1358>,
#   <sqlalchemy.ext.automap.population at 0x1c91461ae10>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c91461a8d0>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c91461a898>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c91461ac88>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c914625400>,
#   <sqlalchemy.ext.automap.population at 0x1c91be78128>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c91be78550>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c924ac0438>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c924ac0400>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c924ac0c88>,
#   <sqlalchemy.ext.automap.population at 0x1c924ac0a90>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c924ac05f8>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c924ac00f0>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c924ac0828>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c924ac0240>,
#   <sqlalchemy.ext.automap.population at 0x1c92b9f15c0>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c92b9f1128>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92b9f1860>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92b9f17b8>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92b9f17f0>,
#   <sqlalchemy.ext.automap.population at 0x1c92ba0a358>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c92ba0a390>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92ba0a4a8>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92ba0a588>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92ba0a4e0>,
#   <sqlalchemy.ext.automap.population at 0x1c92ba0a780>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c92ba0a898>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92ba0a7f0>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92ba0acc0>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92ba0a748>,
#   <sqlalchemy.ext.automap.population at 0x1c92ba0ac88>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c92ba0aa20>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92ba0aac8>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92ba19d30>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92ba19c88>,
#   <sqlalchemy.ext.automap.population at 0x1c92ba19f60>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c92ba19d68>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92ba19e10>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92ba19be0>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92ba19a90>,
#   <sqlalchemy.ext.automap.population at 0x1c92ba19940>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c92ba196a0>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92ba19c18>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92ba190b8>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92ba192e8>,
#   <sqlalchemy.ext.automap.population at 0x1c92ba192b0>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c92ba19240>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c92ba19438>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c92ba194e0>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c92ba19588>,
#   <sqlalchemy.ext.automap.population at 0x1c92ba19400>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c92ba195f8>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c932e76dd8>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c932e76cf8>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c932e76c18>,
#   <sqlalchemy.ext.automap.population at 0x1c932e76518>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c932e760b8>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c932e76160>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c932e76208>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c932e762b0>,
#   <sqlalchemy.ext.automap.population at 0x1c932e76358>),
#  (<sqlalchemy.ext.automap.housing_index at 0x1c932e76400>,
#   <sqlalchemy.ext.automap.oilprice at 0x1c932e764a8>,
#   <sqlalchemy.ext.automap.energy_extraction_employees at 0x1c932e765c0>,
#   <sqlalchemy.ext.automap.nonfarm_employees at 0x1c932e76668>,
#   <sqlalchemy.ext.automap.population at 0x1c932e76710>)]

# %%
for data in results:
    pop_dict = {}
    pop_dict["year"] = data.housing_index.year
    pop_dict["population"] = data.population.population
    
    pop.append(pop_dict)

pop
# Out:
# [{'year': 2000, 'population': 4739414},
#  {'year': 2001, 'population': 4851189},
#  {'year': 2002, 'population': 4978638},
#  {'year': 2003, 'population': 5084017},
#  {'year': 2004, 'population': 5190444},
#  {'year': 2005, 'population': 5299566},
#  {'year': 2006, 'population': 5484883},
#  {'year': 2007, 'population': 5597674},
#  {'year': 2008, 'population': 5726705},
#  {'year': 2009, 'population': 5867489},
#  {'year': 2010, 'population': 5947409},
#  {'year': 2011, 'population': 6056366},
#  {'year': 2012, 'population': 6184861},
#  {'year': 2013, 'population': 6330656},
#  {'year': 2014, 'population': 6503618},
#  {'year': 2015, 'population': 6676565},
#  {'year': 2016, 'population': 6812260},
#  {'year': 2017, 'population': 6905695},
#  {'year': 2018, 'population': 6997384},
#  {'year': 2000, 'population': 4739414},
#  {'year': 2001, 'population': 4851189},
#  {'year': 2002, 'population': 4978638},
#  {'year': 2003, 'population': 5084017},
#  {'year': 2004, 'population': 5190444},
#  {'year': 2005, 'population': 5299566},
#  {'year': 2006, 'population': 5484883},
#  {'year': 2007, 'population': 5597674},
#  {'year': 2008, 'population': 5726705},
#  {'year': 2009, 'population': 5867489},
#  {'year': 2010, 'population': 5947409},
#  {'year': 2011, 'population': 6056366},
#  {'year': 2012, 'population': 6184861},
#  {'year': 2013, 'population': 6330656},
#  {'year': 2014, 'population': 6503618},
#  {'year': 2015, 'population': 6676565},
#  {'year': 2016, 'population': 6812260},
#  {'year': 2017, 'population': 6905695},
#  {'year': 2018, 'population': 6997384}]

# %%
pop = []
for data in results:
    pop_dict = {}
    

pop
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-f18b7ef3740f> in <module>
#       2 for data in results:
#       3     pop_dict = {}
# ----> 4     pop_dict["year1"] = data.year
#       5     pop_dict["population"] = data.population
#       6     pop.append(pop_dict)
#
# AttributeError: 'result' object has no attribute 'year'
